# %% [markdown]
# **FEATURE ENGINEERING**

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

sales_df = pd.read_csv("./data/Warehouse_and_Retail_Sales.csv")

sales_df['TOTAL_SALES'] = sales_df['RETAIL SALES'] * sales_df['WAREHOUSE SALES']


high_value_sales_df = sales_df[sales_df['TOTAL_SALES'] > 100] 

high_value_sales_df.head(100) 


# make a new total sales.
# Out:
#       YEAR  MONTH                             SUPPLIER ITEM CODE  \
# 5230  2017      5            STE MICHELLE WINE ESTATES    101974
# 5248  2017      5             ALLAGASH BREWING COMPANY     10271
# 5278  2017      5       JACKSON FAMILY ENTERPRISES INC     10413
# 5280  2017      5        BUCK DISTRIBUTING COMPANY INC     10430
# 5282  2017      5                  KATCEF BROTHERS INC     10431
# ...    ...    ...                                  ...       ...
# 6658  2017      5    REPUBLIC NATIONAL DISTRIBUTING CO     22616
# 6661  2017      5     THE BROOKLYN BREWERY CORPORATION     22633
# 6663  2017      5  GLOBAL OCEAN AND AIR CARGO SERVICES     22647
# 6667  2017      5                       THE WINE GROUP     22691
# 6683  2017      5                   ANHEUSER BUSCH INC     22904
#
#                              ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 5230                CH ST MICH P/GRIS - 750ML      WINE         12.38
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
sales_df = pd.read_csv("./data/Warehouse_and_Retail_Sales.csv")

sales_df['Retail_to_Warehouse_Ratio'] = sales_df['RETAIL SALES'] / sales_df['WAREHOUSE SALES']


ratio_of_retailsales_wareousesales = sales_df[sales_df['Retail_to_Warehouse_Ratio'] > .0] 

ratio_of_retailsales_wareousesales.head(100) 


# make a new total sales
#Retail_to_Warehouse_Ratio = RETAIL SALES / WAREHOUSE SALES
# Out:
#       YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 2913  2017     10                            Default     59978
# 5207  2017      5                    ROYAL WINE CORP    100200
# 5209  2017      5               DIONYSOS IMPORTS INC    100293
# 5212  2017      5           SANTA MARGHERITA USA INC    100749
# 5213  2017      5  REPUBLIC NATIONAL DISTRIBUTING CO    100803
# ...    ...    ...                                ...       ...
# 5344  2017      5    OPICI FAMILY DISTRIBUTING OF MD     10676
# 5345  2017      5    OPICI FAMILY DISTRIBUTING OF MD     10677
# 5346  2017      5    OPICI FAMILY DISTRIBUTING OF MD     10678
# 5349  2017      5  REPUBLIC NATIONAL DISTRIBUTING CO     10693
# 5350  2017      5                        LEGENDS LTD     10696
#
#                                      ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 2913                         STORE SPECIAL BEER QUART       REF          0.25
# ...
